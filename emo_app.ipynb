# %%
import os
import cv2
import numpy as np
import keras.utils as image
import warnings
warnings.filterwarnings("ignore")
from keras.utils import load_img, img_to_array 
from keras.models import  load_model
import matplotlib.pyplot as plt
import numpy as np

# load model
model = load_model("best_model.h5")


face_haar_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')


cap = cv2.VideoCapture(0)

while True:
    ret, test_img = cap.read()  # captures frame and returns boolean value and captured image
    if not ret:
        continue
    gray_img = cv2.cvtColor(test_img, cv2.COLOR_BGR2RGB)

    faces_detected = face_haar_cascade.detectMultiScale(gray_img, 1.32, 5)

    for (x, y, w, h) in faces_detected:
        cv2.rectangle(test_img, (x, y), (x + w, y + h), (255, 0, 0), thickness=7)
        roi_gray = gray_img[y:y + w, x:x + h]  # cropping region of interest i.e. face area from  image
        roi_gray = cv2.resize(roi_gray, (224, 224))
        img_pixels = image.img_to_array(roi_gray)
        img_pixels = np.expand_dims(img_pixels, axis=0)
        img_pixels /= 255

        predictions = model.predict(img_pixels)

        # find max indexed array
        max_index = np.argmax(predictions[0])

        emotions = ('angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral')
        predicted_emotion = emotions[max_index]

        cv2.putText(test_img, predicted_emotion, (int(x), int(y)), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2)

    resized_img = cv2.resize(test_img, (1000, 700))
    cv2.imshow('Facial emotion analysis ', resized_img)

    if cv2.waitKey(10) == ord('q'):  # wait until 'q' key is pressed
        break

cap.release()
cv2.destroyAllWindows
# Out:
# Metal device set to: Apple M1
# 2023-03-09 02:22:32.524207: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-03-09 02:22:32.524580: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 1   HIToolbox                           0x00000001940b2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x0000000193f8c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x0000000193f8c184 _ZN15MenuBarInstance14EnableAutoShowEv + 56
# 4   HIToolbox                           0x0000000193f2f310 SetMenuBarObscured + 372
# 5   HIToolbox                           0x0000000193f2eee8 _ZN13HIApplication15HandleActivatedEP14OpaqueEventRefhP15OpaqueWindowPtrh + 172
# 6   HIToolbox                           0x0000000193f28fcc _ZN13HIApplication13EventObserverEjP14OpaqueEventRefPv + 296
# 7   HIToolbox                           0x0000000193eefcd0 _NotifyEventLoopObservers + 176
# 8   HIToolbox                           0x0000000193f2896c AcquireEventFromQueue + 432
# 9   HIToolbox                           0x0000000193f17c84 ReceiveNextEventCommon + 320
# 10  HIToolbox                           0x0000000193f17b2c _BlockUntilNextEventMatchingListInModeWithFilter + 72
# 11  AppKit                              0x000000018dabd84c _DPSNextEvent + 632
# 12  AppKit                              0x000000018dabc9dc -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 728
# 13  cv2.abi3.so                         0x0000000139336d2c cvWaitKey + 344
# 14  cv2.abi3.so                         0x0000000139330e64 _ZN2cv9waitKeyExEi + 168
# 15  cv2.abi3.so                         0x0000000139330f5c _ZN2cv7waitKeyEi + 48
# 16  cv2.abi3.so                         0x00000001388f98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 17  python3.10                          0x00000001020dca68 cfunction_call + 80
# 18  python3.10                          0x000000010208a050 _PyObject_MakeTpCall + 612
# 19  python3.10                          0x0000000102178ed0 call_function + 676
# 20  python3.10                          0x0000000102174bc8 _PyEval_EvalFrameDefault + 26388
# 21  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 22  python3.10                          0x000000010216d370 PyEval_EvalCode + 120
# 23  python3.10                          0x0000000102168ee8 builtin_exec + 836
# 24  python3.10                          0x00000001020dd7c4 cfunction_vectorcall_FASTCALL + 200
# 25  python3.10                          0x0000000102178e38 call_function + 524
# 26  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 27  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 28  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 29  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 30  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 31  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 32  python3.10                          0x00000001020a3408 gen_send + 52
# 33  python3.10                          0x000000010209768c method_vectorcall_O + 152
# 34  python3.10                          0x0000000102178e38 call_function + 524
# 35  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 36  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 37  python3.10                          0x0000000102178e38 call_function + 524
# 38  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 39  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 40  python3.10                          0x0000000102178e38 call_function + 524
# 41  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 42  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 43  python3.10                          0x000000010208d708 method_vectorcall + 164
# 44  python3.10                          0x000000010208a894 PyVectorcall_Call + 156
# 45  python3.10                          0x0000000102174f40 _PyEval_EvalFrameDefault + 27276
# 46  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 47  python3.10                          0x000000010208d708 method_vectorcall + 164
# 48  python3.10                          0x0000000102178e38 call_function + 524
# 49  python3.10                          0x0000000102174ca8 _PyEval_EvalFrameDefault + 26612
# 50  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 51  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 52  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 53  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 54  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 55  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 56  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 57  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 58  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 59  _asyncio.cpython-310-darwin.so      0x0000000102f8ffc4 task_step + 548
# 60  _asyncio.cpython-310-darwin.so      0x0000000102f90d28 task_wakeup + 136
# 61  python3.10                          0x00000001020dd430 cfunction_vectorcall_O + 252
# 62  python3.10                          0x0000000102191958 context_run + 348
# 63  python3.10                          0x00000001020dd688 cfunction_vectorcall_FASTCALL_KEYWORDS + 112
# 64  python3.10                          0x0000000102174f40 _PyEval_EvalFrameDefault + 27276
# 65  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 66  python3.10                          0x0000000102178e38 call_function + 524
# 67  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 68  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 69  python3.10                          0x0000000102178e38 call_function + 524
# 70  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 71  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 72  python3.10                          0x0000000102178e38 call_function + 524
# 73  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 74  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 75  python3.10                          0x0000000102178e38 call_function + 524
# 76  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 77  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 78  python3.10                          0x0000000102178e38 call_function + 524
# 79  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 80  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 81  python3.10                          0x000000010208d708 method_vectorcall + 164
# 82  python3.10                          0x0000000102178e38 call_function + 524
# 83  python3.10                          0x0000000102174bc8 _PyEval_EvalFrameDefault + 26388
# 84  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 85  python3.10                          0x000000010216d370 PyEval_EvalCode + 120
# 86  python3.10                          0x0000000102168ee8 builtin_exec + 836
# 87  python3.10                          0x00000001020dd7c4 cfunction_vectorcall_FASTCALL + 200
# 88  python3.10                          0x0000000102178e38 call_function + 524
# 89  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 90  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 91  python3.10                          0x0000000102178e38 call_function + 524
# 92  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 93  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 94  python3.10                          0x00000001021ecf7c pymain_run_module + 272
# 95  python3.10                          0x00000001021ec5b8 Py_RunMain + 1584
# 96  python3.10                          0x00000001021eda68 pymain_main + 1272
# 97  python3.10                          0x0000000102033dc8 main + 56
# 98  dyld                                0x000000018a42fe50 start + 2544
# 1   HIToolbox                           0x00000001940b2d4c _ZN15MenuBarInstance21IsAutoShowHideAllowedEv + 284
# 2   HIToolbox                           0x0000000193f8c230 _ZN15MenuBarInstance24UpdateAutoShowVisibilityE5Pointh + 40
# 3   HIToolbox                           0x0000000193f90380 _ZL19AutoShowHideHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 104
# 4   HIToolbox                           0x0000000193ef04c0 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 1092
# 5   HIToolbox                           0x0000000193eef940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 6   HIToolbox                           0x0000000193eef7d0 SendEventToEventTargetWithOptions + 44
# 7   HIToolbox                           0x0000000193f2f9cc _ZL29ToolboxEventDispatcherHandlerP25OpaqueEventHandlerCallRefP14OpaqueEventRefPv + 472
# 8   HIToolbox                           0x0000000193ef0968 _ZL23DispatchEventToHandlersP14EventTargetRecP14OpaqueEventRefP14HandlerCallRec + 2284
# 9   HIToolbox                           0x0000000193eef940 _ZL30SendEventToEventTargetInternalP14OpaqueEventRefP20OpaqueEventTargetRefP14HandlerCallRec + 356
# 10  HIToolbox                           0x0000000193f05bb8 SendEventToEventTarget + 40
# 11  AppKit                              0x000000018dabcf00 -[NSApplication(NSEvent) _nextEventMatchingEventMask:untilDate:inMode:dequeue:] + 2044
# 12  cv2.abi3.so                         0x0000000139336d2c cvWaitKey + 344
# 13  cv2.abi3.so                         0x0000000139330e64 _ZN2cv9waitKeyExEi + 168
# 14  cv2.abi3.so                         0x0000000139330f5c _ZN2cv7waitKeyEi + 48
# 15  cv2.abi3.so                         0x00000001388f98f0 _ZL19pyopencv_cv_waitKeyP7_objectS0_S0_ + 148
# 16  python3.10                          0x00000001020dca68 cfunction_call + 80
# 17  python3.10                          0x000000010208a050 _PyObject_MakeTpCall + 612
# 18  python3.10                          0x0000000102178ed0 call_function + 676
# 19  python3.10                          0x0000000102174bc8 _PyEval_EvalFrameDefault + 26388
# 20  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 21  python3.10                          0x000000010216d370 PyEval_EvalCode + 120
# 22  python3.10                          0x0000000102168ee8 builtin_exec + 836
# 23  python3.10                          0x00000001020dd7c4 cfunction_vectorcall_FASTCALL + 200
# 24  python3.10                          0x0000000102178e38 call_function + 524
# 25  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 26  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 27  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 28  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 29  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 30  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 31  python3.10                          0x00000001020a3408 gen_send + 52
# 32  python3.10                          0x000000010209768c method_vectorcall_O + 152
# 33  python3.10                          0x0000000102178e38 call_function + 524
# 34  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 35  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 36  python3.10                          0x0000000102178e38 call_function + 524
# 37  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 38  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 39  python3.10                          0x0000000102178e38 call_function + 524
# 40  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 41  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 42  python3.10                          0x000000010208d708 method_vectorcall + 164
# 43  python3.10                          0x000000010208a894 PyVectorcall_Call + 156
# 44  python3.10                          0x0000000102174f40 _PyEval_EvalFrameDefault + 27276
# 45  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 46  python3.10                          0x000000010208d708 method_vectorcall + 164
# 47  python3.10                          0x0000000102178e38 call_function + 524
# 48  python3.10                          0x0000000102174ca8 _PyEval_EvalFrameDefault + 26612
# 49  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 50  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 51  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 52  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 53  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 54  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 55  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 56  python3.10                          0x0000000102170dbc _PyEval_EvalFrameDefault + 10504
# 57  python3.10                          0x00000001020a2e34 gen_send_ex2 + 516
# 58  _asyncio.cpython-310-darwin.so      0x0000000102f8ffc4 task_step + 548
# 59  _asyncio.cpython-310-darwin.so      0x0000000102f90d28 task_wakeup + 136
# 60  python3.10                          0x00000001020dd430 cfunction_vectorcall_O + 252
# 61  python3.10                          0x0000000102191958 context_run + 348
# 62  python3.10                          0x00000001020dd688 cfunction_vectorcall_FASTCALL_KEYWORDS + 112
# 63  python3.10                          0x0000000102174f40 _PyEval_EvalFrameDefault + 27276
# 64  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 65  python3.10                          0x0000000102178e38 call_function + 524
# 66  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 67  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 68  python3.10                          0x0000000102178e38 call_function + 524
# 69  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 70  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 71  python3.10                          0x0000000102178e38 call_function + 524
# 72  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 73  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 74  python3.10                          0x0000000102178e38 call_function + 524
# 75  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 76  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 77  python3.10                          0x0000000102178e38 call_function + 524
# 78  python3.10                          0x0000000102174ba0 _PyEval_EvalFrameDefault + 26348
# 79  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 80  python3.10                          0x000000010208d708 method_vectorcall + 164
# 81  python3.10                          0x0000000102178e38 call_function + 524
# 82  python3.10                          0x0000000102174bc8 _PyEval_EvalFrameDefault + 26388
# 83  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 84  python3.10                          0x000000010216d370 PyEval_EvalCode + 120
# 85  python3.10                          0x0000000102168ee8 builtin_exec + 836
# 86  python3.10                          0x00000001020dd7c4 cfunction_vectorcall_FASTCALL + 200
# 87  python3.10                          0x0000000102178e38 call_function + 524
# 88  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 89  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 90  python3.10                          0x0000000102178e38 call_function + 524
# 91  python3.10                          0x0000000102174c38 _PyEval_EvalFrameDefault + 26500
# 92  python3.10                          0x000000010216dba8 _PyEval_Vector + 2056
# 93  python3.10                          0x00000001021ecf7c pymain_run_module + 272
# 94  python3.10                          0x00000001021ec5b8 Py_RunMain + 1584
# 95  python3.10                          0x00000001021eda68 pymain_main + 1272
# 96  python3.10                          0x0000000102033dc8 main + 56
# 97  dyld                                0x000000018a42fe50 start + 2544
# 2023-03-09 02:22:38.473048: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-03-09 02:22:38.667415: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 411ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 14ms/step
# <function destroyAllWindows>
